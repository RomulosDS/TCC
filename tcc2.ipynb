# %%
import numpy as np
import pandas as pd
import os

# %%
merged2 = pd.read_csv('datasets_consolidados/merged.csv') # Load merged log dataframe

# %%
merged2.drop(merged2.index[merged2['Severity'] == 'Normal'], inplace = True) # Remove alerts with Severity = Normal.

# %%
merged2
# Out:
#         Server  Severity                 Date  \
# 1     server01  Critical  2014-04-01 22:16:12
# 2     server01  Critical  2014-04-01 22:16:17
# 3     server01  Critical  2014-04-07 21:24:24
# 4     server01  Critical  2014-04-07 21:24:29
# 5     server01  Critical  2014-04-14 10:49:41
# ...        ...       ...                  ...
# 5956  server30  Critical  2019-05-06 17:22:32
# 5957  server30  Critical  2019-05-21 13:35:57
# 5958  server30  Critical  2019-05-21 13:35:57
# 5961  server30  Critical  2019-07-28 06:42:53
# 5962  server30  Critical  2019-07-28 06:42:56
#
#                                       Description    DateOnly  Average_min  \
# 1                Power supply redundancy is lost.  2014-04-01           19
# 2     The power input for power supply 2 is lost.  2014-04-01           19
# 3     The power input for power supply 2 is lost.  2014-04-07           17
# 4                Power supply redundancy is lost.  2014-04-07           17
# ...

# %%
merged2.to_csv(r'datasets_consolidados/merged2.csv', index = False)
